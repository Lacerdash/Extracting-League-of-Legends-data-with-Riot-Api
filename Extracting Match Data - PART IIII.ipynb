# %% [markdown]
# # Extracting League of Legends Match Data using Riot API - PART IIII

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import requests
import time
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %% [markdown]
# importing the MatchId File we generated previously

# %%
# Importing the matchids_df.csv generated in the "Extracting League of Legends Match Data using Riot API - PART I, II and III.ipynb"
matchids_df = pd.read_csv('matchids_df.csv')
print('There is a total of {} matchIds in matchids_df.csv'.format(matchids_df.shape[0]))
# Out:
# There is a total of 37971 matchIds in matchids_df.csv

# %%
matchids_df.head(3)
# Out:
#           matchid
# 0  BR1_2610790841
# 1  BR1_2610780078
# 2  BR1_2610769542

# %% [markdown]
# ## PART 4:
#
# Using the [MATCH-V5 EDNPOINT](https://developer.riotgames.com/apis#match-v5/GET_getMatch) to pull the matches data. With this ENDPOINT we can Get matchdata given a match id

# %% [markdown]
# ### Testing with one match id

# %% [markdown]
# Setting the api_key

# %%
api_key = 'RGAPI-c8c94262-b1a3-4501-a182-68bd6698f40a'

# %% [markdown]
# Setting the api_ulr to make the get request

# %%
# The match id we are going to use is the BR1_2583404284 inserted rigth before the ?api_key=
api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/BR1_2583404284?api_key={}'.format(api_key)  
 
resp = requests.get(api_ulr)
resp.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'BR1_2583404284',
#   'participants': ['tzx5O014rLZrM98l42XxZD9-N-cOXWqoi8FeMpOOP5KSMNv-BVVNqaQB7W0vyumsNVBHRVVjWHrTfw',
#    '6jEznZWk4oV5nXe56vBoZYZF_EjEHZ7RXuCc-r6HvquSUXsMuae30lfO3V2SE8pgn95TblQwWxhlGQ',
#    'nYGlKDJX8D5sAkhW4F0UWxIu9FFzmmau0oy8puArmoFwNYHL1q_q1XcYOMgS_-87exEfLHrtMon-rg',
#    'vbZS6WC35IJtIC-giQhbcI1_UR8UJjylu6FBrFj0_MYNuHsNnkw_DeRD304HziJp-vMW2TfkLl_Czw',
#    '_7cwEDziZ_bbtzNFIZRIKmeqnrwOM3ijML26DTcfzhOYqU6AHJr9x_GpmJOzkDiT9f65Y6RJZ4i7Xw',
#    'mGmuiEyYCdQ6kW0aa1nvCn9B1ci7T5s-Gg4Rtgvb_5nHmSIIvzxNPjR98SbatKiSYW3Srn_l8KX7wQ',
#    'gue3kaBmSozygOUnJwovJ4eFImyiscktmTvxVcgDzuxk_ch8lAw3N4A5Eyrw5xVjhoHR4jz9TnJsYQ',
#    'v91YYISBiPwb-g8ID_eWe37pPiz7r27K1qS0kSBhbxFCgJDKNyL57kOb7wtwTn3EOXggBMA9btkBEw',
#    'u3z4ZWNSfoZjzZL5ztBCBLqUzQkvyAqrIKsyD43KEZuW5LBgviFm5LptZP-lDILVLibzLEcZNFc1CA',
#    '6ig7Yf8O9gCs5Ak56TFulo0LcguA-lEExrty3ukZD-oRHYu1eOOfpoYg4_gv14x7EWumRI-86uHatQ']},
#  'info': {'gameCreation': 1661728836215,
#   'gameDuration': 2245,
#   'gameEndTimestamp': 1661731199572,
#   'gameId': 2583404284,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-2583404284',
#   'gameStartTimestamp': 1661728954351,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '12.16.462.4391',
#   'mapId': 11,
#   'participants': [{'assists': 6,
#     'baronKills': 0,
#     'basicPings': 2,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 444,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 447.95667537154594,
#      'damageTakenOnTeamPercentage': 0.21943921226755211,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1253.6208063220552,
#      'earliestDragonTakedown': 1535.2978517314145,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 23,
#      'enemyJungleMonsterKills': 6.5,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 773.5108017868595,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 381.0021110212875,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.30303030303030304,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 64,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 34.25,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'moreEnemyJungleThanOpponent': -126.00000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6664,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 24,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 3,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 11,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.15174011706521484,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'thirdInhibitorDestroyedTime': 2216.774999553323,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 10,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.19384318590164185,
#      'visionScorePerMinute': 0.7191117025693617,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 21605,
#     'champLevel': 18,
#     'championId': 77,
#     'championName': 'Udyr',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 6658,
#     'damageDealtToObjectives': 14677,
#     'damageDealtToTurrets': 6658,
#     'damageSelfMitigated': 70289,
#     'deaths': 2,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 14258,
#     'goldSpent': 13600,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 1026,
#     'item1': 6664,
#     'item2': 3158,
#     'item3': 3121,
#     'item4': 4401,
#     'item5': 3742,
#     'item6': 3340,
#     'itemsPurchased': 18,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1150,
#     'magicDamageDealt': 129628,
#     'magicDamageDealtToChampions': 10048,
#     'magicDamageTaken': 11345,
#     'neutralMinionsKilled': 19,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 480, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 3509, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 20, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 407, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8401, 'var1': 880, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 1104, 'var2': 1943, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 60824,
#     'physicalDamageDealtToChampions': 6714,
#     'physicalDamageTaken': 20521,
#     'profileIcon': 3592,
#     'puuid': 'tzx5O014rLZrM98l42XxZD9-N-cOXWqoi8FeMpOOP5KSMNv-BVVNqaQB7W0vyumsNVBHRVVjWHrTfw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 58,
#     'spell2Casts': 133,
#     'spell3Casts': 109,
#     'spell4Casts': 144,
#     'summoner1Casts': 7,
#     'summoner1Id': 6,
#     'summoner2Casts': 1,
#     'summoner2Id': 12,
#     'summonerId': 'cvoIouh_SLHkSZ4uz83XFct61nAZyQWmKaKZ2n-YoZhyFTs',
#     'summonerLevel': 293,
#     'summonerName': 'disgraça peIada',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 40,
#     'timePlayed': 2245,
#     'totalDamageDealt': 209647,
#     'totalDamageDealtToChampions': 16763,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 33268,
#     'totalHeal': 13311,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 235,
#     'totalTimeCCDealt': 1099,
#     'totalTimeSpentDead': 89,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 19195,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 1401,
#     'turretKills': 3,
#     'turretTakedowns': 5,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 7,
#     'wardsPlaced': 11,
#     'win': True},
#    {'assists': 5,
#     'baronKills': 2,
#     'basicPings': 30,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 460,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 126.00000023841858,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 500,
#      'buffsStolen': 3,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5899306414397885,
#      'controlWardsPlaced': 10,
#      'damagePerMinute': 1102.8622993509935,
#      'damageTakenOnTeamPercentage': 0.3312421745478259,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 4,
#      'earliestBaron': 1253.6208063220552,
#      'earliestDragonTakedown': 482.08748783993536,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 28.000000029802322,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 1,
#      'epicMonsterStolenWithoutSmite': 1,
#      'firstTurretKilledTime': 773.5108017868595,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'goldPerMinute': 577.1230765610078,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 60.000000059604645,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 2,
#      'kda': 4.166666666666667,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.7575757575757576,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 5,
#      'killsNearEnemyTurret': 6,
#      'killsOnLanersEarlyJungleAsJungler': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 2,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 34.59999996423721,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'moreEnemyJungleThanOpponent': -66.00000002980232,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 1,
#      'mythicItemUsed': 6691,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 8,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 1,
#      'riftHeraldTakedowns': 2,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 3,
#      'skillshotsDodged': 45,
#      'skillshotsHit': 43,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 8,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 25,
#      'takedownsAfterGainingLevelAdvantage': 1,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 8,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.3735817850499247,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'thirdInhibitorDestroyedTime': 2216.774999553323,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 10,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.3500819206237793,
#      'visionScorePerMinute': 1.1654892669040366,
#      'wardTakedowns': 10,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 21097,
#     'champLevel': 18,
#     'championId': 121,
#     'championName': 'Khazix',
#     'championTransform': 0,
#     'consumablesPurchased': 14,
#     'damageDealtToBuildings': 1794,
#     'damageDealtToObjectives': 67799,
#     'damageDealtToTurrets': 1794,
#     'damageSelfMitigated': 34374,
#     'deaths': 6,
#     'detectorWardsPlaced': 10,
#     'doubleKills': 1,
#     'dragonKills': 2,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 21597,
#     'goldSpent': 18825,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3142,
#     'item1': 6691,
#     'item2': 3111,
#     'item3': 3814,
#     'item4': 6696,
#     'item5': 6694,
#     'item6': 3364,
#     'itemsPurchased': 35,
#     'killingSprees': 5,
#     'kills': 20,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 490,
#     'magicDamageDealt': 12565,
#     'magicDamageDealtToChampions': 2442,
#     'magicDamageTaken': 13262,
#     'neutralMinionsKilled': 206,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 1,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 1627, 'var2': 1263, 'var3': 0},
#         {'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8321, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 2526, 'var2': 500, 'var3': 0},
#         {'perk': 8014, 'var1': 1063, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 254736,
#     'physicalDamageDealtToChampions': 36945,
#     'physicalDamageTaken': 34115,
#     'profileIcon': 5316,
#     'puuid': '6jEznZWk4oV5nXe56vBoZYZF_EjEHZ7RXuCc-r6HvquSUXsMuae30lfO3V2SE8pgn95TblQwWxhlGQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 244,
#     'spell2Casts': 114,
#     'spell3Casts': 73,
#     'spell4Casts': 29,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 21,
#     'summoner2Id': 11,
#     'summonerId': 'uwGRt5--aPWykOKUJJbBhJ4fdygSeqBAaK8HcGwKfPl0Ng',
#     'summonerLevel': 284,
#     'summonerName': 'Meriga Megamente',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 11,
#     'timePlayed': 2245,
#     'totalDamageDealt': 294846,
#     'totalDamageDealtToChampions': 41272,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 50218,
#     'totalHeal': 25740,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 29,
#     'totalTimeCCDealt': 372,
#     'totalTimeSpentDead': 241,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 27545,
#     'trueDamageDealtToChampions': 1884,
#     'trueDamageTaken': 2841,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 43,
#     'visionWardsBoughtInGame': 11,
#     'wardsKilled': 10,
#     'wardsPlaced': 10,
#     'win': True},
#    {'assists': 4,
#     'baronKills': 0,
#     'basicPings': 22,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 361,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 24.000000029802322,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.32885826566968823,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 832.9422171799486,
#      'damageTakenOnTeamPercentage': 0.21267375740611938,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1253.6208063220552,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 14,
#      'enemyJungleMonsterKills': 13.900000035762787,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 773.5108017868595,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 401.5841747594543,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.5,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.2727272727272727,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 8,
#      'laneMinionsFirst10Minutes': 81,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 79.35000005364418,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'moreEnemyJungleThanOpponent': -126.00000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 40,
#      'skillshotsHit': 69,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 3,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 8,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2821494945657714,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'thirdInhibitorDestroyedTime': 2216.774999553323,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 10,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.07543385028839111,
#      'visionScorePerMinute': 0.6819380960713209,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 19262,
#     'champLevel': 18,
#     'championId': 268,
#     'championName': 'Azir',
#     'championTransform': 0,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 4781,
#     'damageDealtToObjectives': 13668,
#     'damageDealtToTurrets': 4781,
#     'damageSelfMitigated': 25235,
#     'deaths': 6,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 15028,
#     'goldSpent': 14100,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3157,
#     'item1': 6655,
#     'item2': 4645,
#     'item3': 3135,
#     'item4': 3108,
#     'item5': 3020,
#     'item6': 3363,
#     'itemsPurchased': 27,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 794,
#     'magicDamageDealt': 208219,
#     'magicDamageDealtToChampions': 28177,
#     'magicDamageTaken': 14123,
#     'neutralMinionsKilled': 48,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5003, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 885, 'var2': 692, 'var3': 0},
#         {'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 1468, 'var3': 0},
#         {'perk': 8237, 'var1': 1033, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 12754,
#     'physicalDamageDealtToChampions': 2166,
#     'physicalDamageTaken': 16934,
#     'profileIcon': 590,
#     'puuid': 'nYGlKDJX8D5sAkhW4F0UWxIu9FFzmmau0oy8puArmoFwNYHL1q_q1XcYOMgS_-87exEfLHrtMon-rg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 112,
#     'spell2Casts': 208,
#     'spell3Casts': 29,
#     'spell4Casts': 12,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 7,
#     'summoner2Id': 12,
#     'summonerId': 'oeDiQghXwiHQS_FUS5yBWmEHX03pu-fciWsCD0yDAKOWaA',
#     'summonerLevel': 238,
#     'summonerName': 'fernando5050',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 23,
#     'timePlayed': 2245,
#     'totalDamageDealt': 226425,
#     'totalDamageDealtToChampions': 31171,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 32243,
#     'totalHeal': 6351,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 223,
#     'totalTimeCCDealt': 313,
#     'totalTimeSpentDead': 221,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5451,
#     'trueDamageDealtToChampions': 827,
#     'trueDamageTaken': 1184,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 25,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 2,
#     'wardsPlaced': 13,
#     'win': True},
#    {'assists': 5,
#     'baronKills': 0,
#     'basicPings': 2,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 739,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 8.5,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 257.47682234185214,
#      'damageTakenOnTeamPercentage': 0.15618233749630106,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 3,
#      'earliestBaron': 1253.6208063220552,
#      'earliestDragonTakedown': 1172.0569792403603,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 566.0197143554688,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 6.000000029802322,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 773.5108017868595,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 351.2946821497842,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.3333333333333333,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.24242424242424243,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 23,
#      'laneMinionsFirst10Minutes': 52,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 1,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 0,
#      'moreEnemyJungleThanOpponent': -126.00000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6673,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 35,
#      'skillshotsHit': 221,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 10,
#      'survivedSingleDigitHpCount': 1,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 8,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.08721728084825825,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'thirdInhibitorDestroyedTime': 2216.774999553323,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 10,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.4436337351799011,
#      'visionScorePerMinute': 0.6823312593839364,
#      'wardTakedowns': 5,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 15151,
#     'champLevel': 16,
#     'championId': 221,
#     'championName': 'Zeri',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 5061,
#     'damageDealtToObjectives': 17571,
#     'damageDealtToTurrets': 5061,
#     'damageSelfMitigated': 14499,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 13146,
#     'goldSpent': 12100,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 2,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 1036,
#     'item1': 6673,
#     'item2': 3006,
#     'item3': 3046,
#     'item4': 3036,
#     'item5': 1043,
#     'item6': 3363,
#     'itemsPurchased': 26,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 597,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 927,
#     'magicDamageDealt': 26100,
#     'magicDamageDealtToChampions': 4199,
#     'magicDamageTaken': 8272,
#     'neutralMinionsKilled': 26,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 9, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 361, 'var2': 160, 'var3': 0},
#         {'perk': 9104, 'var1': 25, 'var2': 0, 'var3': 0},
#         {'perk': 8017, 'var1': 517, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8429, 'var1': 67, 'var2': 11, 'var3': 10},
#         {'perk': 8451, 'var1': 205, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 93357,
#     'physicalDamageDealtToChampions': 5165,
#     'physicalDamageTaken': 14521,
#     'profileIcon': 1593,
#     'puuid': 'vbZS6WC35IJtIC-giQhbcI1_UR8UJjylu6FBrFj0_MYNuHsNnkw_DeRD304HziJp-vMW2TfkLl_Czw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 651,
#     'spell2Casts': 53,
#     'spell3Casts': 28,
#     'spell4Casts': 7,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 7,
#     'summonerId': 'SLfojGw_Tm5C-oxGoBZoRHBfZYuMCsNNYTXnxnUuA7VSGBg',
#     'summonerLevel': 174,
#     'summonerName': 'JL do serrão ',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 4,
#     'timePlayed': 2245,
#     'totalDamageDealt': 202313,
#     'totalDamageDealtToChampions': 9635,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23678,
#     'totalHeal': 4151,
#     'totalHealsOnTeammates': 566,
#     'totalMinionsKilled': 186,
#     'totalTimeCCDealt': 91,
#     'totalTimeSpentDead': 212,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 82857,
#     'trueDamageDealtToChampions': 269,
#     'trueDamageTaken': 884,
#     'turretKills': 3,
#     'turretTakedowns': 4,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 25,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 5,
#     'wardsPlaced': 10,
#     'win': True},
#    {'assists': 9,
#     'baronKills': 0,
#     'basicPings': 3,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 249,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 310.8928001732025,
#      'damageTakenOnTeamPercentage': 0.08046251828220156,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1253.6208063220552,
#      'earliestDragonTakedown': 1172.0569792403603,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 884.52783203125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 21,
#      'enemyJungleMonsterKills': 4,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilledTime': 773.5108017868595,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 257.0760236896546,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.30303030303030304,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 6,
#      'laneMinionsFirst10Minutes': 10,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 29,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -126.00000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6655,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 34,
#      'skillshotsHit': 52,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 36,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.10531132247083091,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 2,
#      'thirdInhibitorDestroyedTime': 2216.774999553323,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 10,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.177392840385437,
#      'visionScorePerMinute': 1.6543378470215995,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 14112,
#     'champLevel': 15,
#     'championId': 99,
#     'championName': 'Lux',
#     'championTransform': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 1695,
#     'damageDealtToObjectives': 6245,
#     'damageDealtToTurrets': 1695,
#     'damageSelfMitigated': 5300,
#     'deaths': 2,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 9620,
#     'goldSpent': 8750,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3853,
#     'item1': 6655,
#     'item2': 3020,
#     'item3': 4628,
#     'item4': 4630,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 14,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1127,
#     'magicDamageDealt': 52695,
#     'magicDamageDealtToChampions': 11131,
#     'magicDamageTaken': 7362,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1606, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 484, 'var3': 0},
#         {'perk': 8210, 'var1': 8, 'var2': 0, 'var3': 0},
#         {'perk': 8236, 'var1': 48, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5}],
#        'style': 8300}]},
#     'physicalDamageDealt': 4294,
#     'physicalDamageDealtToChampions': 502,
#     'physicalDamageTaken': 4744,
#     'profileIcon': 11,
#     'puuid': '_7cwEDziZ_bbtzNFIZRIKmeqnrwOM3ijML26DTcfzhOYqU6AHJr9x_GpmJOzkDiT9f65Y6RJZ4i7Xw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 67,
#     'spell2Casts': 12,
#     'spell3Casts': 154,
#     'spell4Casts': 16,
#     'summoner1Casts': 5,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 3,
#     'summonerId': 'As2ybCxyUG4UJHjv1_B16EMl_-8G2WEBQPOhn2YMLSeiWks',
#     'summonerLevel': 59,
#     'summonerName': 'Alvess1612',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 42,
#     'timePlayed': 2245,
#     'totalDamageDealt': 56990,
#     'totalDamageDealtToChampions': 11634,
#     'totalDamageShieldedOnTeammates': 884,
#     'totalDamageTaken': 12198,
#     'totalHeal': 2846,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 59,
#     'totalTimeCCDealt': 205,
#     'totalTimeSpentDead': 76,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 92,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionScore': 61,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 7,
#     'wardsPlaced': 36,
#     'win': True},
#    {'assists': 1,
#     'baronKills': 0,
#     'basicPings': 36,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 398,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 1.5,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 650.3944667034078,
#      'damageTakenOnTeamPercentage': 0.20012293407118437,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 10,
#      'dodgeSkillShotsSmallWindow': 5,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 14,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 289.86521033379415,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.4,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.18181818181818182,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 61,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 3,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': -122.00000005960464,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6692,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 4,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 50,
#      'skillshotsHit': 29,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 13,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 4,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 0,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.2242057481032418,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.24045336246490479,
#      'visionScorePerMinute': 0.8920245604916169,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 14629,
#     'champLevel': 15,
#     'championId': 126,
#     'championName': 'Jayce',
#     'championTransform': 0,
#     'consumablesPurchased': 9,
#     'damageDealtToBuildings': 557,
#     'damageDealtToObjectives': 2411,
#     'damageDealtToTurrets': 557,
#     'damageSelfMitigated': 17261,
#     'deaths': 10,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 10847,
#     'goldSpent': 10425,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 3,
#     'item0': 3042,
#     'item1': 6692,
#     'item2': 2055,
#     'item3': 6694,
#     'item4': 3158,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 28,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 526,
#     'magicDamageDealt': 18911,
#     'magicDamageDealtToChampions': 4334,
#     'magicDamageTaken': 8759,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8230, 'var1': 20, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 1235, 'var3': 0},
#         {'perk': 8210, 'var1': 10, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 776, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8321, 'var1': 5, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 12, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 135849,
#     'physicalDamageDealtToChampions': 20005,
#     'physicalDamageTaken': 18713,
#     'profileIcon': 5271,
#     'puuid': 'mGmuiEyYCdQ6kW0aa1nvCn9B1ci7T5s-Gg4Rtgvb_5nHmSIIvzxNPjR98SbatKiSYW3Srn_l8KX7wQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 138,
#     'spell2Casts': 85,
#     'spell3Casts': 58,
#     'spell4Casts': 117,
#     'summoner1Casts': 3,
#     'summoner1Id': 12,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'ibKQ4aWFPibPvAg9_GgWOsmH189KcT3GrWj4obdWmnfG1Q',
#     'summonerLevel': 400,
#     'summonerName': 'Mateuzin Vrau',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 12,
#     'timePlayed': 2245,
#     'totalDamageDealt': 157144,
#     'totalDamageDealtToChampions': 24339,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 28107,
#     'totalHeal': 3340,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 216,
#     'totalTimeCCDealt': 119,
#     'totalTimeSpentDead': 396,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2385,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 634,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 33,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 4,
#     'wardsPlaced': 17,
#     'win': False},
#    {'assists': 7,
#     'baronKills': 0,
#     'basicPings': 25,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 480,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 100.40000021457672,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 375,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.11487518010914069,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 615.0237703602453,
#      'damageTakenOnTeamPercentage': 0.3247551258071729,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 7,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 846.2019975389055,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 7,
#      'enemyJungleMonsterKills': 4.000000029802322,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
# ...
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.4256449956496961,
#      'controlWardsPlaced': 9,
#      'damagePerMinute': 259.4118455632697,
#      'damageTakenOnTeamPercentage': 0.15873978406562672,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 13,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 846.2019975389055,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 3731.259765625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 67,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 223.06753129488484,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.2,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.7272727272727273,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 8,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 14,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 11,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'moreEnemyJungleThanOpponent': -122.00000005960464,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 3190,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 133,
#      'skillshotsHit': 22,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 30,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 16,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.08942515639186444,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.21564710140228271,
#      'visionScorePerMinute': 2.011090995355707,
#      'wardTakedowns': 6,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 13237,
#     'champLevel': 15,
#     'championId': 412,
#     'championName': 'Thresh',
#     'championTransform': 0,
#     'consumablesPurchased': 13,
#     'damageDealtToBuildings': 371,
#     'damageDealtToObjectives': 758,
#     'damageDealtToTurrets': 371,
#     'damageSelfMitigated': 30146,
#     'deaths': 5,
#     'detectorWardsPlaced': 9,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 8347,
#     'goldSpent': 8325,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 3,
#     'item0': 3860,
#     'item1': 1057,
#     'item2': 2055,
#     'item3': 3110,
#     'item4': 3111,
#     'item5': 3190,
#     'item6': 3364,
#     'itemsPurchased': 27,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 958,
#     'magicDamageDealt': 15104,
#     'magicDamageDealtToChampions': 7211,
#     'magicDamageTaken': 13086,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5002, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8351, 'var1': 89, 'var2': 694, 'var3': 0},
#         {'perk': 8313, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8453, 'var1': 459, 'var2': 1156, 'var3': 0},
#         {'perk': 8473, 'var1': 778, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 6374,
#     'physicalDamageDealtToChampions': 822,
#     'physicalDamageTaken': 8757,
#     'profileIcon': 4964,
#     'puuid': 'u3z4ZWNSfoZjzZL5ztBCBLqUzQkvyAqrIKsyD43KEZuW5LBgviFm5LptZP-lDILVLibzLEcZNFc1CA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 53,
#     'spell2Casts': 30,
#     'spell3Casts': 34,
#     'spell4Casts': 9,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 14,
#     'summonerId': 'c1iGhF8sJIfrHOxpND8pkwd1BlvBRLfvcOnWIoGioNV8uQc',
#     'summonerLevel': 604,
#     'summonerName': 'dbukis on dtable',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 53,
#     'timePlayed': 2245,
#     'totalDamageDealt': 27513,
#     'totalDamageDealtToChampions': 9707,
#     'totalDamageShieldedOnTeammates': 3731,
#     'totalDamageTaken': 22294,
#     'totalHeal': 1967,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 34,
#     'totalTimeCCDealt': 455,
#     'totalTimeSpentDead': 120,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 6034,
#     'trueDamageDealtToChampions': 1674,
#     'trueDamageTaken': 451,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 75,
#     'visionWardsBoughtInGame': 11,
#     'wardsKilled': 6,
#     'wardsPlaced': 39,
#     'win': False},
#    {'assists': 6,
#     'baronKills': 0,
#     'basicPings': 12,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'abilityUses': 138,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 8.400000005960464,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 750,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.061545316754655605,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 787.6020490557099,
#      'damageTakenOnTeamPercentage': 0.148165245630554,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 2,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 846.2019975389055,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 1062.4000244140625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 13,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 2245.37034073271,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 431.0423929317918,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 4.666666666666667,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.6363636363636364,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 4,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 66,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 51.89999997615814,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'moreEnemyJungleThanOpponent': -122.00000005960464,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'mythicItemUsed': 6672,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 32,
#      'skillshotsHit': 29,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 14,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 1,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.27150431877322173,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'threeWardsOneSweeperCount': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.7973769903182983,
#      'visionScorePerMinute': 1.226406543048398,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 18840,
#     'champLevel': 18,
#     'championId': 51,
#     'championName': 'Caitlyn',
#     'championTransform': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 4582,
#     'damageDealtToObjectives': 10250,
#     'damageDealtToTurrets': 4582,
#     'damageSelfMitigated': 6976,
#     'deaths': 3,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 16130,
#     'goldSpent': 15500,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 3,
#     'item0': 6676,
#     'item1': 3094,
#     'item2': 3006,
#     'item3': 6672,
#     'item4': 3035,
#     'item5': 3031,
#     'item6': 3363,
#     'itemsPurchased': 22,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 1387,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 776,
#     'magicDamageDealt': 5633,
#     'magicDamageDealtToChampions': 1867,
#     'magicDamageTaken': 10493,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2061, 'var2': 1751, 'var3': 0},
#         {'perk': 8009, 'var1': 1954, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 23, 'var2': 10, 'var3': 0},
#         {'perk': 8014, 'var1': 671, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 19, 'var2': 50, 'var3': 0},
#         {'perk': 8236, 'var1': 28, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 220826,
#     'physicalDamageDealtToChampions': 25601,
#     'physicalDamageTaken': 10055,
#     'profileIcon': 5447,
#     'puuid': '6ig7Yf8O9gCs5Ak56TFulo0LcguA-lEExrty3ukZD-oRHYu1eOOfpoYg4_gv14x7EWumRI-86uHatQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 60,
#     'spell2Casts': 53,
#     'spell3Casts': 17,
#     'spell4Casts': 8,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 7,
#     'summonerId': '-CNmwxTFoErQYtiFQL1D6WexzYJU6rIH_E_3LCOLTXLXPw',
#     'summonerLevel': 466,
#     'summonerName': 'sit on satan',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 26,
#     'timePlayed': 2245,
#     'totalDamageDealt': 249859,
#     'totalDamageDealtToChampions': 29474,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 20809,
#     'totalHeal': 5144,
#     'totalHealsOnTeammates': 1062,
#     'totalMinionsKilled': 277,
#     'totalTimeCCDealt': 107,
#     'totalTimeSpentDead': 112,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 23398,
#     'trueDamageDealtToChampions': 2005,
#     'trueDamageTaken': 260,
#     'turretKills': 1,
#     'turretTakedowns': 2,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 45,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 2,
#     'wardsPlaced': 14,
#     'win': False}],
#   'platformId': 'BR1',
#   'queueId': 440,
#   'teams': [{'bans': [{'championId': 157, 'pickTurn': 1},
#      {'championId': 122, 'pickTurn': 2},
#      {'championId': 895, 'pickTurn': 3},
#      {'championId': -1, 'pickTurn': 4},
#      {'championId': 25, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 2},
#      'champion': {'first': True, 'kills': 33},
#      'dragon': {'first': True, 'kills': 4},
#      'inhibitor': {'first': True, 'kills': 3},
#      'riftHerald': {'first': True, 'kills': 2},
#      'tower': {'first': True, 'kills': 11}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 157, 'pickTurn': 6},
#      {'championId': 236, 'pickTurn': 7},
#      {'championId': 238, 'pickTurn': 8},
#      {'championId': 39, 'pickTurn': 9},
#      {'championId': 11, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 22},
#      'dragon': {'first': False, 'kills': 1},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 1}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %% [markdown]
# Now that we were able to get all the match information, we need to understand how the json file is structured so we can acess the data we want.
#
# [Here](https://developer.riotgames.com/apis#match-v5/GET_getMatch) you can find more information about the JSON file generated by this ENDPOINT.
#
# But basically it has two first keys: 'metadata' and 'info'. We will use the 'info' key, because it is where most of the information we want is stored.

# %%
df = pd.json_normalize(resp.json()['metadata'])
df
# Out:
#   dataVersion         matchId  \
# 0           2  BR1_2583404284
#
#                                         participants
# 0  [tzx5O014rLZrM98l42XxZD9-N-cOXWqoi8FeMpOOP5KSM...

# %% [markdown]
# As we can see the `metadata` key has the `dataVersion`, `matchId` and a `participants` list (composed by participants puuid), which are not useful to us.

# %%
df = pd.json_normalize(resp.json()['info'])
df
# Out:
#     gameCreation  gameDuration  gameEndTimestamp      gameId gameMode  \
# 0  1661728836215          2245     1661731199572  2583404284  CLASSIC
#
#                        gameName  gameStartTimestamp      gameType  \
# 0  teambuilder-match-2583404284       1661728954351  MATCHED_GAME
#
#       gameVersion  mapId                                       participants  \
# 0  12.16.462.4391     11  [{'assists': 6, 'baronKills': 0, 'basicPings':...
#
#   platformId  queueId                                              teams  \
# 0        BR1      440  [{'bans': [{'championId': 157, 'pickTurn': 1},...
#
#   tournamentCode
# 0

# %% [markdown]
# The `'info'` key has a lot of information about the match. But the main information is stored inside the `'participants'` column. This column has a list, that contains a dictionary with kill, assist, deaths and other information for each player of the match.
#
# After said that the information we want to get from the `'infoDto'` (Dto means Data transfer object) is the `'participants'` column.

# %%
# Getting the information inside the 'participants' columns
info_participant = pd.json_normalize(resp.json()['info']['participants'])
info_participant.head(1)
# Out:
#    assists  baronKills  basicPings  bountyLevel  champExperience  champLevel  \
# 0        6           0           2            0            21605          18
#
#    championId championName  championTransform  consumablesPurchased  ...  \
# 0          77         Udyr                  0                     1  ...
#
#    perks.statPerks.flex  perks.statPerks.offense  \
# 0                  5008                     5007
#
#                                         perks.styles  \
# 0  [{'description': 'primaryStyle', 'selections':...
#
#    challenges.controlWardTimeCoverageInRiverOrEnemyHalf  \
# 0                                                NaN
#
#    challenges.highestChampionDamage  challenges.highestWardKills  \
# 0                               NaN                          NaN
#
#    challenges.junglerKillsEarlyJungle  \
# 0                                 NaN
#
#    challenges.killsOnLanersEarlyJungleAsJungler  \
# 0                                           NaN
#
#    challenges.fasterSupportQuestCompletion  \
# 0                                      NaN
#
#    challenges.highestCrowdControlScore
# 0                                  NaN
#
# [1 rows x 232 columns]

# %% [markdown]
# Although now know where the important information is stored, not all the information will be used. Therefore I listed the columns that I judged to be the most important and necessary to us.
#
# Which will be these ones:

# %%
useful_columns = ['assists', 'champLevel', 'championName', 'deaths', 'detectorWardsPlaced', 'gameEndedInEarlySurrender', 
                'gameEndedInSurrender', 'goldEarned', 'inhibitorsLost', 'kills', 'magicDamageDealt', 'magicDamageDealtToChampions', 
                'neutralMinionsKilled', 'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'profileIcon', 
                'sightWardsBoughtInGame', 'teamId', 'teamPosition', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalMinionsKilled', 
                'trueDamageDealt', 'trueDamageDealtToChampions', 'turretsLost', 'visionScore', 'wardsKilled', 'wardsPlaced', 'win'
                ]

print('The original dataset has {}, I choose to use {} columns'.format(info_participant.shape[1], len(useful_columns)))
# Out:
# The original dataset has 232, I choose to use 30 columns

# %% [markdown]
# In the end what we want to get is a dataframe like the one bellow for each matchId in our matchids_df.

# %%
info_participant = pd.json_normalize(resp.json()['info']['participants'])
info_participant = info_participant[useful_columns] # Selecting only the columns from the "useful_columns" list to update the DF
info_participant
# Out:
#    assists  champLevel championName  deaths  detectorWardsPlaced  \
# 0        6          18         Udyr       2                    0
# 1        5          18       Khazix       6                   10
# 2        4          18         Azir       6                    4
# 3        5          16         Zeri       6                    0
# 4        9          15          Lux       2                    0
# 5        1          15        Jayce      10                    4
# 6        7          16      Shyvana       8                    1
# 7        5          17      Orianna       7                    2
# 8       15          15       Thresh       5                    9
# 9        6          18      Caitlyn       3                    2
#
#    gameEndedInEarlySurrender  gameEndedInSurrender  goldEarned  \
# 0                      False                 False       14258
# 1                      False                 False       21597
# 2                      False                 False       15028
# 3                      False                 False       13146
# 4                      False                 False        9620
# 5                      False                 False       10847
# 6                      False                 False       12691
# 7                      False                 False       13259
# 8                      False                 False        8347
# 9                      False                 False       16130
#
#    inhibitorsLost  kills  ...  totalDamageDealt  totalDamageDealtToChampions  \
# 0               0      4  ...            209647                        16763
# 1               0     20  ...            294846                        41272
# 2               0      5  ...            226425                        31171
# 3               0      3  ...            202313                         9635
# 4               0      1  ...             56990                        11634
# 5               3      3  ...            157144                        24339
# 6               3      5  ...            224989                        23015
# 7               3      5  ...            148492                        22021
# 8               3      1  ...             27513                         9707
# 9               3      8  ...            249859                        29474
#
#    totalMinionsKilled  trueDamageDealt  trueDamageDealtToChampions  \
# 0                 235            19195                           0
# 1                  29            27545                        1884
# 2                 223             5451                         827
# 3                 186            82857                         269
# 4                  59                0                           0
# 5                 216             2385                           0
# 6                  85             7304                        1828
# 7                 197             7071                         896
# 8                  34             6034                        1674
# 9                 277            23398                        2005
#
#    turretsLost  visionScore  wardsKilled  wardsPlaced    win
# 0            1           26            7           11   True
# 1            1           43           10           10   True
# 2            1           25            2           13   True
# 3            1           25            5           10   True
# 4            1           61            7           36   True
# 5           11           33            4           17  False
# 6           11           32            8            3  False
# 7           11           23            3           13  False
# 8           11           75            6           39  False
# 9           11           45            2           14  False
#
# [10 rows x 30 columns]

# %% [markdown]
# Now that we have understood how to use the RIOT EDNPOINTS to get a single match data, and which information we want to get from it. We want to be able to repeat this process for all the matchids stored in the matchid_df, merging in the end all the information in 1 DataFrame.
#
# To do that we will create a function that will take as a parameter a DF with a column named "matchid" containing the matchIds, and the api_key. In the end the final result will be a unique DataFrame with all the matches information.

# %%
def get_match_info_by_matchId(match_ids, api_key):

    matchid_info_list = [] # List that will store the dataframes generated, for each match id in the for loop 

    for i in range(len(match_ids)):# len() get the numbers of rows of the match_ids parameter inserted. Then we use the range() function to create a sequence of number starting from 0 to number returned by len(). 
                            # With that we can interate trough each line in the match_ids dataframe (our function parameter) using the iloc function to get the matchid.

        api_ulr = 'https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_ids['matchid'].iloc[i], api_key) # here we use the iloc function as explained above to form the api link for each matchid
        resp = requests.get(api_ulr) # Sending a get request to the api_url
        print(resp.status_code) # Printing the status_code of the request

        if resp.status_code == 200: # Here we need to use if statment, because of the riot API rate limit which is 20 requests every 1 sec and 100 requests every 2 minutes. A 200 status_code means that the request was successful so it can move on.
            pass                        
        elif resp.status_code == 429: # A 429 means that we have exceeded the rate limit. To solve that we need to wait and then try again to get a successful request
            while True: # To do taht we use a while true loop, to execute the if, elif statment repeatdly until the status_code is 200. After that we use break statement to come out of this loop.
                if resp.status_code == 429: 
                    print('429 delay try 10 second') #approximate 110 second wait to work
                    time.sleep(10) # Sleep

                    api_url = 'https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_ids['matchid'].iloc[i], api_key) # Trying the request again
                    resp = requests.get(api_url)
                    print(resp.status_code)

                elif resp.status_code == 200:
                    print('limit cost resolve')
                    break        

        # Same process we did in the beginning             
        matchid_info = pd.json_normalize(resp.json()['info']['participants'])
        matchid_info_list.append(matchid_info) # Merging all the dataframes generated and then stored in the matchid_info_list with the concat() function
        
    matchid_info_df = pd.concat(matchid_info_list)

    return matchid_info_df

# %%
print('There is a total of {} matchIds in matchids_df.csv'.format(matchids_df.shape[0]))
# Out:
# There is a total of 37971 matchIds in matchids_df.csv

# %% [markdown]
# Since the DataFrame has 37.971 rows it would took a tremendous amount of time to loop trough it. Not only because of the rate limit, but also because, in many cases, when I tried to do that an unexpected error occured in the middle of the code and you simple lose all the information.
#
# So I dicided to take a sample of 10.000, which is a considerable amount, and separate it in 10 parts of 1.000 to make it easier to gather all the information.

# %%
# Dividing the sample DF
matchids_df_reduced = matchids_df.sample(10000, random_state = 57)

matchids_sample_1 = matchids_df_reduced.iloc[:1000]
matchids_sample_2 = matchids_df_reduced.iloc[1000:2000]
matchids_sample_3 = matchids_df_reduced.iloc[2000:3000]
matchids_sample_4 = matchids_df_reduced.iloc[3000:4000]
matchids_sample_5 = matchids_df_reduced.iloc[4000:5000]
matchids_sample_6 = matchids_df_reduced.iloc[5000:6000]
matchids_sample_7 = matchids_df_reduced.iloc[6000:7000]
matchids_sample_8 = matchids_df_reduced.iloc[7000:8000]
matchids_sample_9 = matchids_df_reduced.iloc[8000:9000]
matchids_sample_10 = matchids_df_reduced.iloc[9000:10000]

# %%
matchid_info_df_1 = get_match_info_by_matchId(matchids_sample_1, api_key)
matchid_info_df_1.to_csv('matchid_info_df_1.csv', index = False)

# %%
matchid_info_df_2 = get_match_info_by_matchId(matchids_sample_2, api_key)
matchid_info_df_2.to_csv('matchid_info_df_2.csv', index = False)

# %%
matchid_info_df_3 = get_match_info_by_matchId(matchids_sample_3, api_key)
matchid_info_df_3.to_csv('matchid_info_df_3.csv', index = False)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# C:\Users\ferna\AppData\Local\Temp\ipykernel_15552\3574952722.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   matchid_info_df.reset_index(inplace=True)

# %%
matchid_info_df_4 = get_match_info_by_matchId(matchids_sample_4, api_key)
matchid_info_df_4.to_csv('matchid_info_df_4.csv', index = False)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_5 = get_match_info_by_matchId(matchids_sample_5, api_key)
matchid_info_df_5.to_csv('matchid_info_df_5.csv', index = False)
# Out:
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_6 = get_match_info_by_matchId(matchids_sample_6, api_key)
matchid_info_df_6.to_csv('matchid_info_df_6.csv', index = False)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_7 = get_match_info_by_matchId(matchids_sample_7, api_key)
matchid_info_df_7.to_csv('matchid_info_df_7.csv', index = False)
# Out:
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_8 = get_match_info_by_matchId(matchids_sample_8, api_key)
matchid_info_df_8.to_csv('matchid_info_df_8.csv', index = False)
# Out:
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_9 = get_match_info_by_matchId(matchids_sample_9, api_key)
matchid_info_df_9.to_csv('matchid_info_df_9.csv', index = False)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
matchid_info_df_10 = get_match_info_by_matchId(matchids_sample_10, api_key)
matchid_info_df_10.to_csv('matchid_info_df_10.csv', index = False)
# Out:
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 429
# 429 delay try 10 second
# 200
# limit cost resolve
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [markdown]
# Reading all the 10 DFs saved, to create 1 unique DF to store all the matches information

# %%
matchid_info_df_list = []
for i in range(1, 11):
    df = pd.read_csv('matchid_info_df_{}.csv'.format(i))
    matchid_info_df_list.append(df)

matchData_df= pd.concat(matchid_info_df_list)
matchData_df
# Out:
#       assists  baronKills  basicPings  bountyLevel  champExperience  \
# 0           4           0        14.0            1             9053
# 1           7           0        39.0            3             9669
# 2           4           0        19.0            5             9442
# 3           2           0        54.0            3             7208
# 4           6           0        24.0            1             4748
# ...       ...         ...         ...          ...              ...
# 9995        3           0         1.0            0             7996
# 9996        8           0        15.0            0            11486
# 9997       20           0        11.0            4            10461
# 9998        2           0        12.0            0             9016
# 9999        6           0        21.0            0             6725
#
#       champLevel  championId championName  championTransform  \
# 0             12         516         Ornn                  0
# 1             12          30      Karthus                  0
# 2             12         101       Xerath                  0
# 3             10          22         Ashe                  0
# 4              8          57       Maokai                  0
# ...          ...         ...          ...                ...
# 9995          11          92        Riven                  0
# 9996          14          64       LeeSin                  0
# 9997          13         163      Taliyah                  0
# 9998          12         145        Kaisa                  0
# 9999          10         555         Pyke                  0
#
#       consumablesPurchased  ...  challenges.earliestBaron  \
# 0                        3  ...                       NaN
# 1                        2  ...                       NaN
# 2                        5  ...                       NaN
# 3                        5  ...                       NaN
# 4                        9  ...                       NaN
# ...                    ...  ...                       ...
# 9995                     3  ...                       NaN
# 9996                     5  ...                       NaN
# 9997                     4  ...                       NaN
# 9998                     3  ...                       NaN
# 9999                    10  ...                       NaN
#
#       challenges.soloTurretsLategame  challenges.teleportTakedowns  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 9995                             NaN                           NaN
# 9996                             NaN                           NaN
# 9997                             NaN                           NaN
# 9998                             1.0                           NaN
# 9999                             NaN                           NaN
#
#       challenges.thirdInhibitorDestroyedTime  challenges.fastestLegendary  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 9995                                     NaN                          NaN
# 9996                                     NaN                   623.275066
# 9997                                     NaN                          NaN
# 9998                                     NaN                          NaN
# 9999                                     NaN                          NaN
#
#       challenges.shortestTimeToAceFromFirstTakedown  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 9995                                            NaN
# 9996                                      32.231992
# 9997                                      32.231992
# 9998                                      32.231992
# 9999                                            NaN
#
#       challenges.hadAfkTeammate  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 9995                        NaN
# 9996                        NaN
# 9997                        NaN
# 9998                        NaN
# 9999                        NaN
#
#       challenges.baronBuffGoldAdvantageOverThreshold  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 9995                                             NaN
# 9996                                             NaN
# 9997                                             NaN
# 9998                                             NaN
# 9999                                             NaN
#
#       challenges.earliestElderDragon  challenges.mejaisFullStackInTime
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ...                              ...                               ...
# 9995                             NaN                               NaN
# 9996                             NaN                               NaN
# 9997                             NaN                               NaN
# 9998                             NaN                               NaN
# 9999                             NaN                               NaN
#
# [99980 rows x 238 columns]

# %% [markdown]
# Saving the final matchData_df

# %%
matchData_df.to_csv('matchData_df.csv', index = False)

# %%
useful_columns = ['assists', 'champLevel', 'championName', 'deaths', 'detectorWardsPlaced', 'gameEndedInEarlySurrender', 
                'gameEndedInSurrender', 'goldEarned', 'inhibitorsLost', 'kills', 'magicDamageDealt', 'magicDamageDealtToChampions', 
                'neutralMinionsKilled', 'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'profileIcon', 
                'sightWardsBoughtInGame', 'teamId', 'teamPosition', 'totalDamageDealt', 'totalDamageDealtToChampions', 'totalMinionsKilled', 
                'trueDamageDealt', 'trueDamageDealtToChampions', 'turretsLost', 'visionScore', 'wardsKilled', 'wardsPlaced', 'win'
                ]
